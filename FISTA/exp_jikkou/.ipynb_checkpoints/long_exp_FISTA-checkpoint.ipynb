# %%
from exp_nume_ex import exp_Short_FISTA
from exp_nume_ex import lattice
from exp_nume_ex import exp_kakunou
from exp_nume_ex import exp_qseplot
from exp_nume_ex import exp_Long_FISTA
from exp_nume_ex import exp_parameter
from dir_exp_sci import exp_lattice_sci
from dir_exp_sci import exp_kakunou_sci
from dir_exp_sci import exp_Short_sci
import time
import numpy as np
import pandas as pd
import scipy.optimize as optimize
import scipy.sparse as spsp
import matplotlib.pyplot as plt
import csv
import os

from matplotlib.ticker import ScalarFormatter
from matplotlib.font_manager import FontProperties
from scipy.spatial import distance
from scipy.optimize import linprog
from scipy.optimize import minimize
from collections import defaultdict
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## 長期の均衡解を求める

# %%
E_list = [5]
Col_list = [20]
for Col in Col_list:
    for E in E_list:
        print("="*40)
        print(f"E={E}, K={Col}^2")

        K = Col * Col

        M = 90
        N = 90

        # Scaling * tが格子の最小距離となる。
        Scaling = 300 / Col
        alter_T_num = 0.5

        city_network = lattice.make_lattice(Col)

        # 通勤費用パラメータ
        t = 0.1

        # 距離抵抗パラメータ
        tau = 0.01

        # 総土地供給量
        S_total = 900
        S_bar = S_total / K

        Coordinate_Data = \
        np.array([(city_network['node_dic'][str(i)]['x_pos']*Scaling,
                   city_network['node_dic'][str(i)]['y_pos']*Scaling) for i in range(K)])
        distance_matrix = distance.squareform(distance.pdist(Coordinate_Data))

        theta_firm = 0.17
        theta_house = 0.17

        alpha_1 = 0.4
        alpha_2 = 0.4
        beta_1 = 0.4
        beta_2 = 0.4

        L = 0.2
        eta = 1.2
        p_proj = 1e-3

        RW_ini = 1.0
        RW_proj = 1e-3

        err_short = 1e-5
        err_long = "400iteration"

        m_per = M / K
        m0 = np.array([m_per] * K)
        n0 = np.full((K, K), N / (K * K))

        method = "FISTA"
        dic = "mesh_300divCol"
        
        #パラメータ設定
        prm = exp_parameter.Parameter(
                    Col, distance_matrix, t, tau, Scaling, S_total, S_bar,
                    theta_firm, theta_house, E, RW_proj, alter_T_num,
                    alpha_1, alpha_2, beta_1, beta_2, M, N)
        
        algprm = exp_parameter.Algo_Parameter(L, eta, p_proj)
        
        short = exp_Short_FISTA.Short(prm, algprm)
        long = exp_Long_FISTA.Long(prm, algprm, short)
        
        dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                           fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                           fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/truevalue/jikken_F.xlsx')
        
        dH = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                           fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                           fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/truevalue/jikken_H.xlsx')
        
        # Z_list = np.array(dF['Z'].tolist())
        m_corr = np.array(dF['m'].tolist())
        n_corr = np.array(dH['n'].tolist())
        R_corr = np.array(dF['R'].tolist())
        W_corr = np.array(dF['W'].tolist())
        
        mn_corr = long.bond(m_corr, n_corr)
        RW_corr = np.concatenate((R_corr, W_corr))
        
        obj_corr = long.Z_LP(mn_corr, RW_corr)
        # obj_corr = Z_list[-1]
        # obj_corr = 1.0
        
        start_time = time.process_time()
        m, n, RW, long_iteration, obj_list, obj_rel_list = long.solve(m0, n0, RW_ini, err_short, err_long, obj_corr, long_itr=400)
        end_time = time.process_time()
        elapsed_time = end_time - start_time
        
        print("CPU_time:", elapsed_time, "秒")
        
        R = RW[:prm.K]
        W = RW[prm.K:]
        
        pi = short.pi(R, W, m)
        v = short.v(R, W)
        
        err_long = "obj_smaller_1e-4"
        
        exp_kakunou.long_kakunou_true(m, n, R, W, pi, v, prm, algprm, method, err_short, err_long, dic)
        exp_kakunou.long_kakunou_nume_num(long_iteration, prm, algprm, method, err_short, err_long, dic)
        exp_kakunou.long_kakunou_rel(obj_rel_list, prm, algprm, method, err_short, err_long, dic)
        # exp_kakunou.long_kakunou_val(long_iteration, obj_list, prm, algprm, method, err_short, err_long, dic)
# Out:
# ========================================
# E=5, K=20^2
# klong: 1
# short_max_value: 45
# alpha: 0.1
# klong: 2
# short_max_value: 45
# alpha: 0.1
# klong: 3
# short_max_value: 51
# alpha: 0.1
# klong: 4
# short_max_value: 51
# alpha: 0.1
# klong: 5
# short_max_value: 51
# alpha: 0.1
# klong: 6
# short_max_value: 55
# alpha: 0.1
# klong: 7
# short_max_value: 55
# alpha: 0.1
# klong: 8
# short_max_value: 60
# alpha: 0.1
# klong: 9
# short_max_value: 59
# alpha: 0.1
# klong: 10
# short_max_value: 58
# alpha: 0.1
# klong: 11
# short_max_value: 64
# alpha: 0.1
# klong: 12
# short_max_value: 64
# alpha: 0.1
# klong: 13
# short_max_value: 64
# alpha: 0.1
# klong: 14
# short_max_value: 64
# alpha: 0.1
# klong: 15
# short_max_value: 71
# alpha: 0.1
# klong: 16
# short_max_value: 71
# alpha: 0.1
# klong: 17
# short_max_value: 70
# alpha: 0.1
# klong: 18
# short_max_value: 70
# alpha: 0.1
# klong: 19
# short_max_value: 76
# alpha: 0.1
# klong: 20
# short_max_value: 76
# alpha: 0.1
# klong: 21
# short_max_value: 75
# alpha: 0.1
# klong: 22
# short_max_value: 75
# alpha: 0.1
# klong: 23
# short_max_value: 75
# alpha: 0.1
# klong: 24
# short_max_value: 82
# alpha: 0.1
# klong: 25
# short_max_value: 82
# alpha: 0.1
# klong: 26
# short_max_value: 82
# alpha: 0.1
# klong: 27
# short_max_value: 82
# alpha: 0.1
# klong: 28
# short_max_value: 82
# alpha: 0.1
# klong: 29
# short_max_value: 90
# alpha: 0.1
# klong: 30
# short_max_value: 90
# alpha: 0.1
# klong: 31
# short_max_value: 90
# alpha: 0.1
# klong: 32
# short_max_value: 90
# alpha: 0.1
# klong: 33
# short_max_value: 90
# alpha: 0.1
# klong: 34
# short_max_value: 98
# alpha: 0.1
# klong: 35
# short_max_value: 98
# alpha: 0.1
# klong: 36
# short_max_value: 98
# alpha: 0.1
# klong: 37
# short_max_value: 98
# alpha: 0.1
# klong: 38
# short_max_value: 98
# alpha: 0.1
# klong: 39
# short_max_value: 98
# alpha: 0.1
# klong: 40
# short_max_value: 98
# alpha: 0.1
# klong: 41
# short_max_value: 108
# alpha: 0.1
# klong: 42
# short_max_value: 108
# alpha: 0.1
# klong: 43
# short_max_value: 107
# alpha: 0.1
# klong: 44
# short_max_value: 107
# alpha: 0.1
# klong: 45
# short_max_value: 107
# alpha: 0.1
# klong: 46
# short_max_value: 107
# alpha: 0.1
# klong: 47
# short_max_value: 107
# alpha: 0.1
# klong: 48
# short_max_value: 107
# alpha: 0.1
# klong: 49
# short_max_value: 107
# alpha: 0.1
# klong: 50
# short_max_value: 107
# alpha: 0.1
# klong: 51
# short_max_value: 118
# alpha: 0.1
# klong: 52
# short_max_value: 118
# alpha: 0.1
# klong: 53
# short_max_value: 118
# alpha: 0.1
# klong: 54
# short_max_value: 118
# alpha: 0.1
# klong: 55
# short_max_value: 118
# alpha: 0.1
# klong: 56
# short_max_value: 117
# alpha: 0.1
# klong: 57
# short_max_value: 117
# alpha: 0.1
# klong: 58
# short_max_value: 117
# alpha: 0.1
# klong: 59
# short_max_value: 117
# alpha: 0.1
# klong: 60
# short_max_value: 117
# alpha: 0.1
# klong: 61
# short_max_value: 117
# alpha: 0.1
# klong: 62
# short_max_value: 117
# alpha: 0.1
# klong: 63
# short_max_value: 117
# alpha: 0.1
# klong: 64
# short_max_value: 128
# alpha: 0.1
# klong: 65
# short_max_value: 128
# alpha: 0.1
# klong: 66
# short_max_value: 128
# alpha: 0.1
# klong: 67
# short_max_value: 128
# alpha: 0.1
# klong: 68
# short_max_value: 128
# alpha: 0.1
# klong: 69
# short_max_value: 128
# alpha: 0.1
# klong: 70
# short_max_value: 128
# alpha: 0.1
# klong: 71
# short_max_value: 128
# alpha: 0.1
# klong: 72
# short_max_value: 128
# alpha: 0.1
# klong: 73
# short_max_value: 128
# alpha: 0.1
# klong: 74
# short_max_value: 128
# alpha: 0.1
# klong: 75
# short_max_value: 128
# alpha: 0.1
# klong: 76
# short_max_value: 128
# alpha: 0.1
# klong: 77
# short_max_value: 128
# alpha: 0.1
# klong: 78
# short_max_value: 128
# alpha: 0.1
# klong: 79
# short_max_value: 128
# alpha: 0.1
# klong: 80
# short_max_value: 128
# alpha: 0.1
# klong: 81
# short_max_value: 128
# alpha: 0.1
# klong: 82
# short_max_value: 128
# alpha: 0.1
# klong: 83
# short_max_value: 128
# alpha: 0.1
# klong: 84
# short_max_value: 128
# alpha: 0.1
# klong: 85
# short_max_value: 128
# alpha: 0.1
# klong: 86
# short_max_value: 128
# alpha: 0.1
# klong: 87
# short_max_value: 128
# alpha: 0.1
# klong: 88
# short_max_value: 128
# long_max_value: 88
# Lyapunov: -0.42572572927838337
# CPU_time: 513.15625 秒

# %%
S_H_hat, L_H_hat, S_F, L_F = short.demand_hat(R, W)

# %%
Col = 30

vmin = 0
vmax = prm.S_bar

mat = np.reshape(m * S_F, (Col, Col))

plt.figure(figsize=(5,5))
plt.imshow(mat, interpolation='nearest', vmin = vmin, vmax = vmax, cmap='seismic')

plt.colorbar()

plt.xlabel('m * S_F', fontsize=20)

plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])

plt.show()

# %%
Col = 30

vmin = 0
vmax = None

mat = np.reshape(m, (Col, Col))

plt.figure(figsize=(5,5))
plt.imshow(mat, interpolation='nearest', vmin = vmin, vmax = vmax, cmap='seismic')

plt.colorbar()

plt.xlabel('m', fontsize=20)

plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])

plt.show()

# %%
Col = 30

# 3次元行列の生成
matrix = np.reshape(m * S_F, (Col, Col))

# 行列の座標を作成
x, y = np.meshgrid(range(Col), range(Col))

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, matrix, cmap='viridis')

# グラフの軸ラベル設定
ax.set_xlabel('Col')
ax.set_ylabel('Row')
ax.set_zlabel('m * S_F')

plt.gca().invert_xaxis()

# グラフ表示
plt.show()

# %%
np.max(S_F)
# Out:
# 138.9690270602965

# %%
np.min(S_F)
# Out:
# 0.08966477636731097

# %%
Col = 40

# 3次元行列の生成
matrix = np.reshape(S_F, (Col, Col))

# 行列の座標を作成
x, y = np.meshgrid(range(Col), range(Col))

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, matrix, cmap='viridis')

# グラフの軸ラベル設定
ax.set_xlabel('Col')
ax.set_ylabel('Row')
ax.set_zlabel('Z')

plt.gca().invert_xaxis()

# グラフ表示
plt.show()

# %%
Col = 40

vmin = 0
vmax = None

mat = np.reshape(np.sum(n, axis=0), (Col, Col))

plt.figure(figsize=(5,5))
plt.imshow(mat, interpolation='nearest', vmin = vmin, vmax = vmax, cmap='seismic')

plt.colorbar()

plt.xlabel('m', fontsize=20)

plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])

plt.show()

# %%
Col = 40

# 3次元行列の生成
matrix = np.reshape(m * S_F, (Col, Col))

# 行列の座標を作成
x, y = np.meshgrid(range(Col), range(Col))

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, matrix, cmap='viridis')

# グラフの軸ラベル設定
ax.set_xlabel('Col')
ax.set_ylabel('Row')
ax.set_zlabel('Z')

plt.gca().invert_xaxis()

# グラフ表示
plt.show()

# %%
np.max(np.sum(n, axis=0))
# Out:
# 0.1317452444284022

# %%
np.sum(n, axis=0).reshape(Col, Col)
# Out:
# array([[0.098988  , 0.09899404, 0.09899368, ..., 0.09899368, 0.09899404,
#         0.098988  ],
#        [0.09899404, 0.09900093, 0.09900054, ..., 0.09900054, 0.09900093,
#         0.09899404],
#        [0.09899368, 0.09900054, 0.09900004, ..., 0.09900004, 0.09900054,
#         0.09899368],
#        ...,
#        [0.09899368, 0.09900054, 0.09900004, ..., 0.09900004, 0.09900054,
#         0.09899368],
#        [0.09899404, 0.09900093, 0.09900054, ..., 0.09900054, 0.09900093,
#         0.09899404],
#        [0.098988  , 0.09899404, 0.09899368, ..., 0.09899368, 0.09899404,
#         0.098988  ]])

# %%
Col = 40

# 3次元行列の生成
matrix = np.reshape(np.sum(n, axis=0), (Col, Col)) #どこに通勤しているか

# 行列の座標を作成
x, y = np.meshgrid(range(Col), range(Col))

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, matrix, cmap='viridis')

# グラフの軸ラベル設定
ax.set_xlabel('Col')
ax.set_ylabel('Row')
ax.set_zlabel('Z')

plt.gca().invert_xaxis()

# グラフ表示
plt.show()

# %%
np.max(np.sum(n, axis=1))
# Out:
# 0.10038259248936282

# %%
np.min(np.sum(n, axis=1))
# Out:
# 0.09877748610957629

# %%
Col = 40

# 3次元行列の生成
matrix = np.reshape(np.sum(n, axis=1), (Col, Col))　#どこに住んでいるか

# 行列の座標を作成
x, y = np.meshgrid(range(Col), range(Col))

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, matrix, cmap='viridis')

# グラフの軸ラベル設定
ax.set_xlabel('Col')
ax.set_ylabel('Row')
ax.set_zlabel('Z')

plt.gca().invert_xaxis()

# グラフ表示
plt.show()

# %%
RW_ini = 1.0
err_short = 1e-5
R_next, W_next, \
iteration, R_err, W_err, v_err, pi_err, obj_err, grad_mean, \
R_list, W_list, pi_list, v_list, Z_list = \
     short.short_solve(RW_ini, m, n, err_short, 
                       R_corr=None, W_corr=None, pi_corr=None, v_corr=None, obj_corr=None,
                       short_itr=10000, rel=0)
# Out:
# short_max_value: 67

# %%
mn_d = long.logit(R_next, W_next, m)
m_d, n_d = long.breakingdown(mn_d)

# %%
m - m_d
# Out:
# array([3.16096822e-06, 3.25580032e-06, 3.36160420e-06, ...,
#        3.36160420e-06, 3.25580032e-06, 3.16096822e-06])

# %%
np.mean(m - m_d)
# Out:
# 1.7942461752462614e-17

# %%
np.mean(n - n_d)
# Out:
# -1.1536652269074615e-20

# %%
S_H, L_H, S_F, L_F = short.demand(R_next, W_next)

# %%
np.max(abs(prm.S_bar - np.sum(S_H * n, axis=1) - S_F * m))
# Out:
# 0.0001871129729119625

# %%
prm.E * np.sum(n, axis=0) - np.sum(L_H * n, axis=0) - L_F * m # forall j
# Out:
# array([4.88947695e-05, 4.88681803e-05, 4.88197501e-05, ...,
#        4.88197501e-05, 4.88681803e-05, 4.88947695e-05])

# %% [markdown]
# ## 目的関数描画

# %%
theta_list = [1.0, 2.0, 3.0, 5.0, 6.0, 8.0, 10.0]
Col_list = [10]
for Col in Col_list:
    for theta in theta_list:
        print("="*40)
        print(f"theta={theta}")

        K = Col * Col

        M = 0.1 * K
        N = 0.1 * K

        # Scaling * tが格子の最小距離となる。
        Scaling = 300 / Col
        alter_T_num = 0.5

        city_network = lattice.make_lattice(Col)

        # 通勤費用パラメータ
        t = 0.1

        # 距離抵抗パラメータ
        tau = 0.01

        # 総土地供給量
        S_total = K
        S_bar = S_total / K

        Coordinate_Data = \
        np.array([(city_network['node_dic'][str(i)]['x_pos']*Scaling,
                   city_network['node_dic'][str(i)]['y_pos']*Scaling) for i in range(K)])
        distance_matrix = distance.squareform(distance.pdist(Coordinate_Data))

        theta_firm = 1.0
        theta_house = 1.0

        alpha_1 = 0.4
        alpha_2 = 0.4
        beta_1 = 0.4
        beta_2 = 0.4

        L = 0.2
        eta = 1.2
        p_proj = 1e-3

        RW_ini = 1.0
        RW_proj = 1e-3

        m_per = M / K
        m0 = np.array([m_per] * K)
        n0 = np.full((K, K), N / (K * K))

        method = "FISTA"
        dic = "Scaling=300divCol"

        #パラメータ設定
        prm = exp_Short_FISTA.Parameter(
                    Col, distance_matrix, t, tau, Scaling, S_total, S_bar,
                    theta_firm, theta_house, E, RW_proj, alter_T_num,
                    alpha_1, alpha_2, beta_1, beta_2, M, N)

        algprm = exp_Short_FISTA.Algo_Parameter(L, eta, p_proj)
        short = exp_Short_FISTA.Short(prm, algprm)
        long = exp_Long_FISTA.Long(prm, algprm, short)

        dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                             fr'shortlong/{method}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                             fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/K={Col}^2/val/Z.xlsx')

        iteration = np.array(dF['iteration'].tolist())
        Z_list = np.array(dF['Z'].tolist())

        plt.rcParams['font.family'] = 'serif'
        plt.rcParams['font.serif'] = 'Times New Roman'
        plt.rcParams['mathtext.fontset'] = 'cm'  # 数式フォントもTimes New Romanに設定

        font_path = r'C:\Windows\Fonts\meiryo.ttc'  # フォントのパスを指定
        jp_font = FontProperties(fname=font_path)

        plt.plot(iteration, Z_list, color="k")

        # plt.title('m')
        plt.xlabel('立地点数', fontproperties=jp_font, fontsize=20)
        plt.ylabel('計算回数', fontproperties=jp_font, fontsize=20)

        # plt.yticks([1e-1, 1e-2, 1e-3])
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)

        # plt.xlim(left=1, right=50)
        # plt.ylim(top=1, bottom=-1)

        plt.grid(True)

        plt.subplots_adjust(left=0.17, bottom=0.15)

        # plt.savefig(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/graph/' \
        # fr'short/long_{long}/{method}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/L={algprm.L}/p_proj={algprm.p_proj}/E={prm.E}/' \
        # fr'K={Col_list[0]}^2,{Col_list[1]}^2,{Col_list[2]}^2/val/R.jpg', format='jpg')

        plt.show()
# Out:
# ========================================
# theta=1.0
# ========================================
# theta=2.0
# ========================================
# theta=3.0
# ========================================
# theta=5.0
# ========================================
# theta=6.0
# ========================================
# theta=8.0
# ========================================
# theta=10.0

# %%
import numpy as np
import pandas as pd
import scipy.optimize as optimize
import scipy.sparse as spsp
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from matplotlib.font_manager import FontProperties
import csv
import os


theta_list = [1.0, 2.0, 3.0, 5.0, 6.0, 8.0]
theta_plot_list = []
max_itr_list = []
for theta in theta_list:
    # print("="*40)
    # print(f"E={E}")
    
    Col = 10

    K = Col * Col

    M = 0.1 * K
    N = 0.1 * K

    m_per = M / K
    m_fixed = np.array([m_per] * K)
    n_fixed = np.full((K, K), N / (K * K))

    # Scaling * tが格子の最小距離となる。
    Scaling = 300 / Col
    alter_T_num = 0.5

    city_network = lattice.make_lattice(Col)

    # 通勤費用パラメータ
    t = 0.1

    # 距離抵抗パラメータ
    tau = 0.01

    E = 5

    # 総土地供給量
    S_total = K
    S_bar = S_total / K

    Coordinate_Data = \
    np.array([(city_network['node_dic'][str(i)]['x_pos']*Scaling,
               city_network['node_dic'][str(i)]['y_pos']*Scaling) for i in range(K)])
    distance_matrix = distance.squareform(distance.pdist(Coordinate_Data))

    theta_firm = theta
    theta_house = theta

    alpha_1 = 0.4
    alpha_2 = 0.4
    beta_1 = 0.4
    beta_2 = 0.4

    L = 0.2
    eta = 1.2
    p_proj = 1e-3

    RW_ini = 1.0
    RW_proj = 1e-3
    err_short = 1e-5

    method = "FISTA"
    dic = "Scaling=300divCol"
    long = "ichiyou"

    #パラメータ設定
    prm = exp_parameter.Parameter(
                Col, distance_matrix, t, tau, Scaling, S_total, S_bar,
                theta_firm, theta_house, E, RW_proj, alter_T_num,
                alpha_1, alpha_2, beta_1, beta_2, M, N)

    algprm = exp_parameter.Algo_Parameter(L, eta, p_proj)
    short = exp_Short_FISTA.Short(prm, algprm)

    dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                       fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                       fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/nume_num/nume_num.xlsx')
    
    iteration = np.array(dF['iteration'].tolist())
    
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = 'Times New Roman'
    plt.rcParams['mathtext.fontset'] = 'cm'  # 数式フォントもTimes New Romanに設定

    font_path = r'C:\Windows\Fonts\meiryo.ttc'  # フォントのパスを指定
    jp_font = FontProperties(fname=font_path)
    
    theta_plot_list.append(theta)
    
    max_itr_list.append(np.max(iteration))
    
plt.plot(theta_plot_list, max_itr_list, color="k")

# plt.title('m')
plt.xlabel(r'$\theta$', fontsize=20)
plt.ylabel('計算回数', fontproperties=jp_font, fontsize=20)

# plt.yticks([1e-1, 1e-2, 1e-3])
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.xlim(left=1, right=8)
plt.ylim(top=100, bottom=0)

plt.grid(True)

plt.subplots_adjust(left=0.17, bottom=0.15)

# folder_path = fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/graph/' \
#               fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
#               fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/K={prm.Col}^2/nume_num'

# create_folder(folder_path)

# plt.savefig(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/graph/' \
#             fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
#             fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/K={prm.Col}^2/nume_num/theta.jpg', format='jpg')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 82
#      79 algprm = exp_parameter.Algo_Parameter(L, eta, p_proj)
#      80 short = exp_Short_FISTA.Short(prm, algprm)
# ---> 82 dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
#      83                    fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
#      84                    fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/nume_num/nume_num.xlsx')
#      86 iteration = np.array(dF['iteration'].tolist())
#      88 plt.rcParams['font.family'] = 'serif'
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/shortlong/FISTA/err_short=1e-05/err_long=obj_smaller_1e-4/Scaling=300divCol/RW_proj=0.001/alter_T_num=0.5/L=0.2/eta=1.2/p_proj=0.001/E=5/theta=1.0/K=10^2/nume_num/nume_num.xlsx'

# %%
import numpy as np
import pandas as pd
import scipy.optimize as optimize
import scipy.sparse as spsp
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from matplotlib.font_manager import FontProperties
import csv
import os

Col_list = [20, 30, 40]
for Col in Col_list:

    K = Col * Col

    M = 90
    N = 90

    # Scaling * tが格子の最小距離となる。
    Scaling = 300 / Col
    alter_T_num = 0.5

    city_network = lattice.make_lattice(Col)

    # 通勤費用パラメータ
    t = 0.1

    # 距離抵抗パラメータ
    tau = 0.01

    # 総土地供給量
    S_total = 900
    S_bar = S_total / K

    Coordinate_Data = \
    np.array([(city_network['node_dic'][str(i)]['x_pos']*Scaling,
               city_network['node_dic'][str(i)]['y_pos']*Scaling) for i in range(K)])
    distance_matrix = distance.squareform(distance.pdist(Coordinate_Data))

    theta_firm = 0.1
    theta_house = 0.1

    alpha_1 = 0.4
    alpha_2 = 0.4
    beta_1 = 0.4
    beta_2 = 0.4

    E = 5

    L = 0.2
    eta = 1.2
    p_proj = 1e-3

    RW_ini = 1.0
    RW_proj = 1e-3

    err_short = 1e-5
    err_long = "obj_smaller_1e-4"

    m_per = M / K
    m0 = np.array([m_per] * K)
    n0 = np.full((K, K), N / (K * K))

    method = "FISTA"
    dic = "mesh_300divCol"

    #パラメータ設定
    prm = exp_parameter.Parameter(
                Col, distance_matrix, t, tau, Scaling, S_total, S_bar,
                theta_firm, theta_house, E, RW_proj, alter_T_num,
                alpha_1, alpha_2, beta_1, beta_2, M, N)

    algprm = exp_parameter.Algo_Parameter(L, eta, p_proj)

    dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                       fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                       fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/nume_num/nume_num.xlsx')
    
    dF = pd.read_excel(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/excelfile/' \
                       fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
                       fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/theta={prm.theta_firm}/K={prm.Col}^2/rel/jikken_F.xlsx')

    plt.plot(theta_plot_list, max_itr_list, color="k")
    
    # plt.title('m')
    plt.xlabel(r'$\sqrt{K}$', fontsize=20)
    plt.ylabel('計算回数', fontproperties=jp_font, fontsize=20)

    # plt.yticks([1e-1, 1e-2, 1e-3])
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    # plt.xlim(left=5, right=30)
    # plt.ylim(top=2100, bottom=0)

    plt.grid(True)

    plt.subplots_adjust(left=0.17, bottom=0.15)

    # folder_path = fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/graph/' \
    #               fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
    #               fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/K={prm.Col}^2/nume_num'

    # create_folder(folder_path)

    # plt.savefig(fr'C:/Users/kimura/OneDrive - 国立大学法人東北大学/numerical/short_dual/exp/graph/' \
    #             fr'shortlong/{method}/err_short={err_short}/err_long={err_long}/{dic}/RW_proj={prm.RW_proj}/alter_T_num={prm.alter_T_num}/' \
    #             fr'L={algprm.L}/eta={algprm.eta}/p_proj={algprm.p_proj}/E={prm.E}/K={prm.Col}^2/nume_num/theta.jpg', format='jpg')

    plt.show()
